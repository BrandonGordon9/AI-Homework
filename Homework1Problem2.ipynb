# %% [markdown]
# <a href="https://colab.research.google.com/github/BrandonGordon9/AI-Homework1/blob/master/Homework1Problem2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from mpl_toolkits import mplot3d

# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %%
import numpy as np
np.random.seed(42)

ax = plt.axes(projection='3d')

xs1 = 2 * np.random.rand(100, 1)
xs2 = 2 * np.random.rand(100, 1)
ys = 4 + 3 * xs1 + np.random.rand(100, 1)

ax.scatter3D(xs1, xs2, ys, "b.");
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('y');
ax.axis([0, 2, 0, 15])
# Out:
# [0, 2, 0, 15]

# %%
# split the data into training and test sets
# train set
train_xs1 = xs1[:80]
train_xs2 = xs2[:80]
train_ys = ys[:80]
# test set
test_xs1 = xs1[80:]
test_xs2 = xs2[80:]
test_ys = ys[80:]

# %% [markdown]
# # Linear regression using numpy

# %%
# number of epochs
epochs = 10
# learning rate
lr = 0.01

# %%
# initial values for weights w1, w2, and bias b
w1 = np.random.randn(1)
w2 = np.random.randn(1)
b = np.zeros(1)

# %%
for epoch in np.arange(epochs):
  for i in np.arange(80):
    y_pred = (w1 * train_xs1[i]) + (w2 * train_xs2[i]) + b
    
    grad_w1 = (y_pred - train_ys[i]) * train_xs1[i]
    grad_w2 = (y_pred - train_ys[i]) * train_xs2[i]
    grad_b = (y_pred - train_ys[i])
    
    w1 -= lr * grad_w1
    w2 -= lr * grad_w2
    b -= lr * grad_b

# %%
test_loss = 0
for i in np.arange(20):
  test_loss += 0.5 * ((w1 * test_xs1[i]) + (w2 * test_xs2[i]) + b - test_ys[i]) ** 2
test_loss /= 20

# %%
test_loss
# Out:
# array([0.08743053])

# %%
pred_ys = (w1 * test_xs1) + (w2 * test_xs2) + b

# %%
ax = plt.axes(projection='3d')
ax.scatter3D(test_xs1, test_xs2, test_ys, "b.");
ax.scatter3D(test_xs1, test_xs2, pred_ys, "r.") # predicted values
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('y');
ax.axis([0, 2, 0, 15])
# Out:
# [0, 2, 0, 15]

# %%
b
# Out:
# array([3.836611])

# %%
w1
# Out:
# array([3.25855477])

# %%
w2
# Out:
# array([0.44242038])
